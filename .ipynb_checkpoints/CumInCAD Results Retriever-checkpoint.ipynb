# %%
import requests
url = "http://papers.cumincad.org/cgi-bin/works/Search?search=Scanner&x=0&y=0"

# %%
def main(url):
    """Run the other functions to turn a CumInCAD search into a json of published paper data"""
    
    # Important initialisations
    nextURL = url
    listings = []
    pageCount = 0
    
    # Loop through each page of search results starting at the specified url, gathering links to listings
    while nextURL != "lastPage":
        # Get the HTML
        html = getHTML(nextURL)
        # Split the HTML into listings and add to the list of listings
        listings.extend(getListings(html))
        # Find the link to the next page
        nextURL = getNextURL(html)
        # Count and display the amount of pages
        pageCount += 1
        print("Page number " + str(pageCount))
    
    # Extract just the URL of each listing
    listings = [getListingURL(listing) for listing in listings]
    
    # Looping through each of the listing pages to mine data
    listingCount = 0
    for listing in listings[:4]:
        #print("\n" + listing)
        listingCount += 1
        print("Listing " + str(listingCount))
        listingHTML = getHTML(listing)
        dataPoints = scrapeListingMeta(listingHTML)

# %%
def getNextURL(html):
    """Find the next page's URL from within the previous's HTML"""
    
    # Split the html at the point where the next page icon is used
    parts = html.split('="/woda/icons/flat-noborder/forward.gif"')
    
    # If this icon doesn't occur, return the 'lastPage' flag
    if len(parts) == 1:
        return "lastPage"
    else:
        # Getting the URL
        nextURL = "http://papers.cumincad.org" + parts[0].split("HREF")[-1].split('"')[1]
        
        # Replacing &amp; with &
        nextURL = nextURL.replace("&amp;", "&")
        
        # Returning the new URL
        return nextURL

# %%
def getHTML(url):
    """Get the HTML at a given URL"""
    response = requests.get(url)
    return response.text

# %%
def getListings(fullHTML):
    """Get the listings from the HTML"""
    
    # Cut down to the relevant <div> 
    div = fullHTML.split("<DIV CLASS=RECORDS>")[1].split("</DIV>")[0]
    
    # Get all the table rows, excluding the bit of non-table stuff at the beginning and the first header row
    table = [("<tr" + row).strip() for row in div.split("<tr")[2:]]
    
    # Get rid of a little extraneous bit at the end of the last row
    if table[-1].endswith("</tbody></table><div><br/></div>"):
        table[-1] = table[-1][:-32].strip()
    
    # Joining rows that shouldn't be seperated (there's one row inside each row)
    rowPairs = list(zip(table[::2], table[1::2]))
    rows = [pair[0] + pair[1] for pair in rowPairs]
    return rows

# %%
def getListingURL(listing):
    """Get the URL that corresponds to the detailed page of a listing"""
    return listing.split("<A HREF=")[1].split(">")[0]

# %%
def scrapeListingMeta(html):
    """Return a dictionary of all the metadata in the html of a listing's page"""
    
    # Retrieving a list of each meta point in the HTML
    metaPoints = html.split("<meta")[1:]
    metaPoints = [point.split("/>")[0] for point in metaPoints]
    
    # Looping through the points, adding the data from each string to a dictionary
    listingMeta = {}
    for point in metaPoints:
        print("POINT: " + point)
        point = point.strip()
        points = point.split('"')
        if len(points)

# %%
main(url)
# Out:
# Page number 1
# Page number 2
# Listing 1
# POINT:  name="DC.creator" content="Baraniak, David W."
# POINT:  name="DC.date" content="1987"
# POINT:  name="DC.title" content="Automatic Data Capture: Scanners Offer a Cost-effective Solution"
# POINT:  name="DC.source" content="computer Graphics World November, 1987. vol. 10: pp. 93-94, 97 : ill."
# POINT:  name="DC.description" content=" table. In order to decide whether today&#39;s scanner deliver the price and performance a particular CAAD application demand, the author lists vendors, scanner type, raster to vector conversion editing raster vector, data exchange format and compares them"
# POINT:  name="DC.subject" content="hardware, CAD, scanning, business"
# POINT:  name="DC.type" content="Conference Paper"
# POINT:  name="DC.type" content="PeerReviewed"
# POINT:  name="DC.format" content="application/pdf"
# POINT:  name="DC.identifier" content="http://papers.cumincad.org/data/works/att/"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/Show?2832"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/paper/2832"
# POINT:  name="citation_title" content="Automatic Data Capture: Scanners Offer a Cost-effective Solution">
#
# POINT:  name="citation_author" content="Baraniak, David W.">
#
# POINT:  name="citation_publication_date" content="1987">
#
# POINT:  name="citation_pdf_url" content="http://papers.cumincad.org/data/works/att/">
#
#
# POINT:  name="eprints.creators_name" content="Baraniak, David W."
# POINT:  name="eprints.type" content="Paper"
# POINT:  name="eprints.datestamp" content="2003-06-02 11:58"
# POINT:  name="eprints.lastmod" content="2018-01-15"
# POINT:  name="eprints.metadata_visibility" content="show"
# POINT:  name="eprints.title" content="Automatic Data Capture: Scanners Offer a Cost-effective Solution"
# POINT:  name="eprints.ispublished" content="unpub"
# POINT:  name="eprints.subject" content="CUMINCAD Cumulative Index about publications in Computer Aided Architectural Design"
# POINT:  name="eprints.full_text_status" content="public"
# POINT:  name="eprints.keywords" content="hardware, CAD, scanning, business"
# POINT:  name="eprints.abstract" content=" table. In order to decide whether today&#39;s scanner deliver the price and performance a particular CAAD application demand, the author lists vendors, scanner type, raster to vector conversion editing raster vector, data exchange format and compares them"
# POINT:  name="eprints.date" content="1987"
# POINT:  name="eprints.date_type" content="submitted"
# POINT:  name="eprints.institution" content="CUMINCAD"
# POINT:  name="eprints.department" content="CADline"
# POINT:  name="eprints.citation" content="Baraniak, David W. (1987) &lt;B&gt;Automatic Data Capture: Scanners Offer a Cost-effective Solution&lt;/B&gt; computer Graphics World November, 1987. vol. 10: pp. 93-94, 97 : ill. http://papers.cumincad.org/cgi-bin/works/Show?"
# POINT:  name="eprints.document_url" content="http://papers.cumincad.org/data/works/att/"
# Listing 2
# POINT:  name="DC.creator" content="Boulaassal, H.; Landes, T.; Grussenmeyer, P."
# POINT:  name="DC.date" content="2009"
# POINT:  name="DC.title" content="Automatic Extraction of Planar Clusters and their Contours on Building Facades Recorded by Terrestrial Laser Scanner"
# POINT:  name="DC.source" content="International Journal of Architectural Computing vol. 7 - no. 1, 1-20"
# POINT:  name="DC.description" content="Since 3D city models need to be realistic not only from a bird&#39;s point of view, but also from a pedestrian&#39;s point of view, the interest in the generation of 3D façade models is increasing. This paper presents two successive algorithms for automatically segmenting building façades scanned by Terrestrial Laser Scanner (TLS) into planar clusters and extracting their contours. Since majority of façade components are planes, the topic of automatic extraction of planar features has been studied. The RANSAC algorithm has been chosen among numerous methods. It is a robust estimator frequently used to compute model parameters from a dataset containing outliers, as it occurs in TLS data. Nevertheless, the RANSAC algorithm has been improved in order to extract the most significant planar clusters describing the main features composing the building façades. Subsequently, a second algorithm has been developed for extracting the contours of these features. The innovative idea presented in this paper is the efficient way to detect the points composing the contours. In order to evaluate the performances of both algorithms, they have successively been applied on samples with different characteristics, i.e. densities, types of façades and size of architectural details. Finally, a quality evaluation based on the comparison of planar clusters and contours obtained manually has been carried out. The results prove that the proposed algorithms deliver qualitative as well as quantitative satisfactory results and confirm that both algorithms are reliable for the forthcoming 3D modelling of building façades."
# POINT:  name="DC.subject" content=""
# POINT:  name="DC.type" content="Conference Paper"
# POINT:  name="DC.type" content="PeerReviewed"
# POINT:  name="DC.format" content="application/pdf"
# POINT:  name="DC.identifier" content="http://papers.cumincad.org/data/works/att/ijac20097101.content.pdf"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/Show?ijac20097101"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/paper/ijac20097101"
# POINT:  name="citation_title" content="Automatic Extraction of Planar Clusters and their Contours on Building Facades Recorded by Terrestrial Laser Scanner">
#
# POINT:  name="citation_author" content="Boulaassal, H.; Landes, T.; Grussenmeyer, P.">
#
# POINT:  name="citation_publication_date" content="2009">
#
# POINT:  name="citation_pdf_url" content="http://papers.cumincad.org/data/works/att/ijac20097101.content.pdf">
#
#
# POINT:  name="eprints.creators_name" content="Boulaassal, H.; Landes, T.; Grussenmeyer, P."
# POINT:  name="eprints.type" content="Paper"
# POINT:  name="eprints.datestamp" content="2009-06-23 06:07"
# POINT:  name="eprints.lastmod" content="2018-01-15"
# POINT:  name="eprints.metadata_visibility" content="show"
# POINT:  name="eprints.title" content="Automatic Extraction of Planar Clusters and their Contours on Building Facades Recorded by Terrestrial Laser Scanner"
# POINT:  name="eprints.ispublished" content="unpub"
# POINT:  name="eprints.subject" content="CUMINCAD Cumulative Index about publications in Computer Aided Architectural Design"
# POINT:  name="eprints.full_text_status" content="public"
# POINT:  name="eprints.keywords" content=""
# POINT:  name="eprints.abstract" content="Since 3D city models need to be realistic not only from a bird&#39;s point of view, but also from a pedestrian&#39;s point of view, the interest in the generation of 3D façade models is increasing. This paper presents two successive algorithms for automatically segmenting building façades scanned by Terrestrial Laser Scanner (TLS) into planar clusters and extracting their contours. Since majority of façade components are planes, the topic of automatic extraction of planar features has been studied. The RANSAC algorithm has been chosen among numerous methods. It is a robust estimator frequently used to compute model parameters from a dataset containing outliers, as it occurs in TLS data. Nevertheless, the RANSAC algorithm has been improved in order to extract the most significant planar clusters describing the main features composing the building façades. Subsequently, a second algorithm has been developed for extracting the contours of these features. The innovative idea presented in this paper is the efficient way to detect the points composing the contours. In order to evaluate the performances of both algorithms, they have successively been applied on samples with different characteristics, i.e. densities, types of façades and size of architectural details. Finally, a quality evaluation based on the comparison of planar clusters and contours obtained manually has been carried out. The results prove that the proposed algorithms deliver qualitative as well as quantitative satisfactory results and confirm that both algorithms are reliable for the forthcoming 3D modelling of building façades."
# POINT:  name="eprints.date" content="2009"
# POINT:  name="eprints.date_type" content="submitted"
# POINT:  name="eprints.institution" content="CUMINCAD"
# POINT:  name="eprints.department" content="journal"
# POINT:  name="eprints.citation" content="Boulaassal, H.; Landes, T.; Grussenmeyer, P. (2009) &lt;B&gt;Automatic Extraction of Planar Clusters and their Contours on Building Facades Recorded by Terrestrial Laser Scanner&lt;/B&gt; International Journal of Architectural Computing vol. 7 - no. 1, 1-20 http://papers.cumincad.org/cgi-bin/works/Show?ijac20097101"
# POINT:  name="eprints.document_url" content="http://papers.cumincad.org/data/works/att/ijac20097101.content.pdf"
# Listing 3
# POINT:  name="DC.creator" content="Celani, Gabriela; Laura Cancherini"
# POINT:  name="DC.date" content="2009"
# POINT:  name="DC.title" content="Digitalização tridimensional de objetos: um estudo de caso [Scanning Three-dimensional Objects: A Case Study]"
# POINT:  name="DC.source" content="SIGraDi 2009 - Proceedings of the 13th Congress of the Iberoamerican Society of Digital Graphics, Sao Paulo, Brazil, November 16-18, 2009"
# POINT:  name="DC.description" content="The present research is an exploratory study about medium-range 3D-scanning technologies for architectural applications. Its purpose was to gather information that will subside the future acquisition of a 3D-scanning equipment for the Laboratory for Automation and Prototyping for Architecture and Construction, LAPAC, at the University of Campinas (UNICAMP). In order to test some of these technologies, some experiments were carried out. Museum sculptures were digitized and the results were 3D-printed. Preliminary results show that accurate technologies are still very expensive, but there are some alternative, more accessible technologies, based on photogrammetry, which can lead to fairly good results. "
# POINT:  name="DC.subject" content="Digitalização 3D; scanner 3D; photogrametria; maquete arquitetônica."
# POINT:  name="DC.type" content="Conference Paper"
# POINT:  name="DC.type" content="PeerReviewed"
# POINT:  name="DC.format" content="application/pdf"
# POINT:  name="DC.identifier" content="http://papers.cumincad.org/data/works/att/sigradi2009_1012.content.pdf"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/Show?sigradi2009_1012"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/paper/sigradi2009_1012"
# POINT:  name="citation_title" content="Digitalização tridimensional de objetos: um estudo de caso [Scanning Three-dimensional Objects: A Case Study]">
#
# POINT:  name="citation_author" content="Celani, Gabriela; Laura Cancherini">
#
# POINT:  name="citation_publication_date" content="2009">
#
# POINT:  name="citation_pdf_url" content="http://papers.cumincad.org/data/works/att/sigradi2009_1012.content.pdf">
#
#
# POINT:  name="eprints.creators_name" content="Celani, Gabriela; Laura Cancherini"
# POINT:  name="eprints.type" content="Paper"
# POINT:  name="eprints.datestamp" content="2016-03-10 08:48"
# POINT:  name="eprints.lastmod" content="2018-01-15"
# POINT:  name="eprints.metadata_visibility" content="show"
# POINT:  name="eprints.title" content="Digitalização tridimensional de objetos: um estudo de caso [Scanning Three-dimensional Objects: A Case Study]"
# POINT:  name="eprints.ispublished" content="unpub"
# POINT:  name="eprints.subject" content="CUMINCAD Cumulative Index about publications in Computer Aided Architectural Design"
# POINT:  name="eprints.full_text_status" content="public"
# POINT:  name="eprints.keywords" content="Digitalização 3D; scanner 3D; photogrametria; maquete arquitetônica."
# POINT:  name="eprints.abstract" content="The present research is an exploratory study about medium-range 3D-scanning technologies for architectural applications. Its purpose was to gather information that will subside the future acquisition of a 3D-scanning equipment for the Laboratory for Automation and Prototyping for Architecture and Construction, LAPAC, at the University of Campinas (UNICAMP). In order to test some of these technologies, some experiments were carried out. Museum sculptures were digitized and the results were 3D-printed. Preliminary results show that accurate technologies are still very expensive, but there are some alternative, more accessible technologies, based on photogrammetry, which can lead to fairly good results. "
# POINT:  name="eprints.date" content="2009"
# POINT:  name="eprints.date_type" content="submitted"
# POINT:  name="eprints.institution" content="CUMINCAD"
# POINT:  name="eprints.department" content="SIGRADI"
# POINT:  name="eprints.citation" content="Celani, Gabriela; Laura Cancherini (2009) &lt;B&gt;Digitalização tridimensional de objetos: um estudo de caso [Scanning Three-dimensional Objects: A Case Study]&lt;/B&gt; SIGraDi 2009 - Proceedings of the 13th Congress of the Iberoamerican Society of Digital Graphics, Sao Paulo, Brazil, November 16-18, 2009 http://papers.cumincad.org/cgi-bin/works/Show?sigradi2009_1012"
# POINT:  name="eprints.document_url" content="http://papers.cumincad.org/data/works/att/sigradi2009_1012.content.pdf"
# Listing 4
# POINT:  name="DC.creator" content="Cheng, Chi-Li and Hou, June-Hao"
# POINT:  name="DC.date" content="2016"
# POINT:  name="DC.title" content="Biomimetic Robotic Construction Process - An approach for adapting mass irregular-shaped natural materials"
# POINT:  name="DC.source" content="Herneoja, Aulikki; Toni Österlund and Piia Markkanen (eds.), Complexity &amp; Simplicity - Proceedings of the 34th eCAADe Conference - Volume 1, University of Oulu, Oulu, Finland, 22-26 August 2016, pp. 133-142"
# POINT:  name="DC.description" content="Beaver dams are formed by two main processes. One is that beavers select proper woods for constructing. The other one is that streams aggregate those woods to be assembled. Using this approach to construction structure is suitable for natural environment. In this paper, we attempt to develop a construction process which is suitable for all-terrain construction robot in the future. This construction process is inspired by beavers&#39; construction behavior in nature. Beavers select proper sticks to make the structure stable. We predict that particular properties of sticks contribute gravity-driven assembly of wood structure. Thus, we implement the system with machine learning to find proper properties of sticks to improve selection mechanism of construction process. During this construction process, 3D scanner on robotic arm scans and recognizes sticks on terrain, and then robot will select proper sticks and place them. After placement, the system will scan and record the results for learning mechanism."
# POINT:  name="DC.subject" content="Biomimetic Design; Machine Learning; Natural Material; Point Cloud Analysis; Robotic Fabrication"
# POINT:  name="DC.type" content="Conference Paper"
# POINT:  name="DC.type" content="PeerReviewed"
# POINT:  name="DC.format" content="application/pdf"
# POINT:  name="DC.identifier" content="http://papers.cumincad.org/data/works/att/ecaade2016_079.pdf"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/Show?ecaade2016_079"
# POINT:  name="DC.relation" content="http://papers.cumincad.org/cgi-bin/works/paper/ecaade2016_079"
# POINT:  name="citation_title" content="Biomimetic Robotic Construction Process - An approach for adapting mass irregular-shaped natural materials">
#
# POINT:  name="citation_author" content="Cheng, Chi-Li and Hou, June-Hao">
#
# POINT:  name="citation_publication_date" content="2016">
#
# POINT:  name="citation_pdf_url" content="http://papers.cumincad.org/data/works/att/ecaade2016_079.pdf">
#
#
# POINT:  name="eprints.creators_name" content="Cheng, Chi-Li and Hou, June-Hao"
# POINT:  name="eprints.type" content="Paper"
# POINT:  name="eprints.datestamp" content="2017-06-28 08:46"
# POINT:  name="eprints.lastmod" content="2018-01-15"
# POINT:  name="eprints.metadata_visibility" content="show"
# POINT:  name="eprints.title" content="Biomimetic Robotic Construction Process - An approach for adapting mass irregular-shaped natural materials"
# POINT:  name="eprints.ispublished" content="unpub"
# POINT:  name="eprints.subject" content="CUMINCAD Cumulative Index about publications in Computer Aided Architectural Design"
# POINT:  name="eprints.full_text_status" content="public"
# POINT:  name="eprints.keywords" content="Biomimetic Design; Machine Learning; Natural Material; Point Cloud Analysis; Robotic Fabrication"
# POINT:  name="eprints.abstract" content="Beaver dams are formed by two main processes. One is that beavers select proper woods for constructing. The other one is that streams aggregate those woods to be assembled. Using this approach to construction structure is suitable for natural environment. In this paper, we attempt to develop a construction process which is suitable for all-terrain construction robot in the future. This construction process is inspired by beavers&#39; construction behavior in nature. Beavers select proper sticks to make the structure stable. We predict that particular properties of sticks contribute gravity-driven assembly of wood structure. Thus, we implement the system with machine learning to find proper properties of sticks to improve selection mechanism of construction process. During this construction process, 3D scanner on robotic arm scans and recognizes sticks on terrain, and then robot will select proper sticks and place them. After placement, the system will scan and record the results for learning mechanism."
# POINT:  name="eprints.date" content="2016"
# POINT:  name="eprints.date_type" content="submitted"
# POINT:  name="eprints.institution" content="CUMINCAD"
# POINT:  name="eprints.department" content="eCAADe"
# POINT:  name="eprints.citation" content="Cheng, Chi-Li and Hou, June-Hao (2016) &lt;B&gt;Biomimetic Robotic Construction Process - An approach for adapting mass irregular-shaped natural materials&lt;/B&gt; Herneoja, Aulikki; Toni Österlund and Piia Markkanen (eds.), Complexity &amp; Simplicity - Proceedings of the 34th eCAADe Conference - Volume 1, University of Oulu, Oulu, Finland, 22-26 August 2016, pp. 133-142 http://papers.cumincad.org/cgi-bin/works/Show?ecaade2016_079"
# POINT:  name="eprints.document_url" content="http://papers.cumincad.org/data/works/att/ecaade2016_079.pdf"
